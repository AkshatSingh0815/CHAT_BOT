# %%
# !git clone https://github.com/AkshatSingh0815/CHAT_BOT
# Out:
# Cloning into 'CHAT_BOT'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 25 (delta 4), reused 21 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 26.38 MiB | 21.26 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
pip install Flask python-dotenv langchain langchain-community langchain-classic langchain-text-splitters langchain-groq langchain-core faiss-cpu sentence-transformers pypdf pydantic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 72.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.9/382.9 kB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# %cd CHAT_BOT
from app import app
app.run(deug=True)
# Out:
# /content/CHAT_BOT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3065/85526700.py in <cell line: 0>()
#       1 get_ipython().run_line_magic('cd', 'CHAT_BOT')
# ----> 2 from app import app
#       3 app.run(deug=True)
#
# /content/CHAT_BOT/app.py in <module>
#       3 from flask import Flask, render_template, request, jsonify, session
#       4 from dotenv import load_dotenv
# ----> 5 from rag_engine import RAGEngine
#       6 from intent_router import is_claim_query
#       7 load_dotenv()
#
# /content/CHAT_BOT/rag_engine.py in <module>
#       4 from langchain_community.vectorstores import FAISS
#       5 from langchain_community.embeddings import HuggingFaceEmbeddings
# ----> 6 from langchain_community.document_loaders import PyPDFLoader
#       7 from langchain_text_splitters import RecursiveCharacterTextSplitter
# ...

# %%
# 1. Define your variables
GIT_TOKEN = "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"
GIT_USERNAME = "AkshatSingh0815"
GIT_EMAIL = "akshatsinghsssihl@gmail.com"

# 2. Configure Git global settings
# !git config --global user.name "{GIT_USERNAME}"
# !git config --global user.email "{GIT_EMAIL}"

# %%
# Stage all changes
# !git add .

# Create your commit message
# !git commit -m "Pushed changes from Google Colab"

# Push back to GitHub (change 'main' to 'master' if using an older repo template)
# !git push origin main
# Out:
# [main 9baafb8] Pushed changes from Google Colab
#  466 files changed, 1867184 insertions(+), 731 deletions(-)
#  create mode 100644 DATA/84_Guidelines-on-Claim-Settlement.pdf
#  create mode 100644 DATA/Claimsss_merged.pdf
#  create mode 100644 DATA/DATA_FINAL_EXECUTE.pdf
#  create mode 100644 DATA/final.pdf
#  rewrite app.py (68%)
#  create mode 100644 ocr_pipeline.py
#  create mode 100644 poppler-25.12.0/Library/bin/Lerc.dll
#  create mode 100644 poppler-25.12.0/Library/bin/cairo.dll
#  create mode 100644 poppler-25.12.0/Library/bin/charset.dll
#  create mode 100644 poppler-25.12.0/Library/bin/deflate.dll
#  create mode 100644 poppler-25.12.0/Library/bin/expat.dll
#  create mode 100644 poppler-25.12.0/Library/bin/fontconfig-1.dll
#  create mode 100644 poppler-25.12.0/Library/bin/freetype.dll
#  create mode 100644 poppler-25.12.0/Library/bin/iconv.dll
#  create mode 100644 poppler-25.12.0/Library/bin/jpeg8.dll
#  create mode 100644 poppler-25.12.0/Library/bin/lcms2.dll
# ...
